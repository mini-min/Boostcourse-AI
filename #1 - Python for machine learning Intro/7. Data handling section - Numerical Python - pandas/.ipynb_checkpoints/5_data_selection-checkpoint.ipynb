# %%
import pandas as pd

# %% [markdown]
# #### Data loading
# - xlrd 모듈이 없을 경우, conda install xlrd

# %%
# !conda install --y xlrd
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/min/miniconda3
#
#   added / updated specs:
#     - xlrd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.26 |       hca03da5_2         116 KB
#     certifi-2021.5.30          |   py38hca03da5_1         139 KB
#     conda-4.11.0               |   py38hca03da5_0        14.4 MB
#     xlrd-2.0.1                 |     pyhd3eb1b0_0          90 KB
#     ------------------------------------------------------------
#                                            Total:        14.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   xlrd               pkgs/main/noarch::xlrd-2.0.1-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2021.4.13-hca03da5_1 --> 2021.10.26-hca03da5_2
# ...

# %%
import numpy as np
df = pd.read_csv('data.csv', encoding='cp949')
df.head() #처음 다섯줄 출력
# Out:
#    연번   센터유형                    센터명       운영기관               시설명   우편번호  \
# 0   1  중앙/권역        코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동   4562
# 1   2  중앙/권역      코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층  31212
# 2   3  중앙/권역      코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층  61452
# 3   4  중앙/권역      코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층  50612
# 4   5     지역  코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관  41931
#
#                       주소       사무실전화번호
# 0    서울특별시 중구 을지로 39길 29  02-2260-7114
# 1  충청남도 천안시 동남구 천안대로 357           NaN
# 2      광주광역시 동구 필문대로 365  062-220-3739
# 3    경상남도 양산시 물금읍 금오로 20  055-360-6701
# 4          대구시 중구 달성로 56  053-661-3955

# %% [markdown]
# #### data selction with index number and column names

# %%
df["센터명"].head(2)
# Out:
# 0      코로나19 중앙 예방접종센터
# 1    코로나19 중부권역 예방접종센터
# Name: 센터명, dtype: object

# %%
df[["센터명", "운영기관", "시설명"]].head(3)
# Out:
#                  센터명       운영기관             시설명
# 0    코로나19 중앙 예방접종센터    국립중앙의료원      국립중앙의료원 D동
# 1  코로나19 중부권역 예방접종센터  순천향대 천안병원  천안시 실내배드민턴장 1층
# 2  코로나19 호남권역 예방접종센터      조선대병원  조선대학교병원 의성관 5층

# %%
df[:10]
# Out:
#    연번   센터유형                      센터명       운영기관               시설명   우편번호  \
# 0   1  중앙/권역          코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동   4562
# 1   2  중앙/권역        코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층  31212
# 2   3  중앙/권역        코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층  61452
# 3   4  중앙/권역        코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층  50612
# 4   5     지역    코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관  41931
# 5   6     지역   코로나19 서울특별시 성동구 예방접종센터        NaN      성동구청 대강당(3층)   4750
# 6   7     지역  코로나19 부산광역시 부산진구 예방접종센터        NaN      부산시민공원 시민사랑채  47197
# 7   8     지역   코로나19 인천광역시 연수구 예방접종센터        NaN       선학경기장 선학체육관  21908
# 8   9     지역    코로나19 광주광역시 서구 예방접종센터        NaN            빛고을체육관  62048
# 9  10     지역   코로나19 대전광역시 유성구 예방접종센터        NaN         유성종합스포츠센터  34128
#
#                       주소       사무실전화번호
# 0    서울특별시 중구 을지로 39길 29  02-2260-7114
# 1  충청남도 천안시 동남구 천안대로 357           NaN
# ...

# %%
df["센터명"][:3]
# Out:
# 0      코로나19 중앙 예방접종센터
# 1    코로나19 중부권역 예방접종센터
# 2    코로나19 호남권역 예방접종센터
# Name: 센터명, dtype: object

# %%
account_serires = df["센터명"]
account_serires[:3]
# Out:
# 0      코로나19 중앙 예방접종센터
# 1    코로나19 중부권역 예방접종센터
# 2    코로나19 호남권역 예방접종센터
# Name: 센터명, dtype: object

# %%
account_serires[[1,5,2]]
# Out:
# 1         코로나19 중부권역 예방접종센터
# 5    코로나19 서울특별시 성동구 예방접종센터
# 2         코로나19 호남권역 예방접종센터
# Name: 센터명, dtype: object

# %%
account_serires[account_serires<250000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9910b9630056> in <module>
# ----> 1 account_serires[account_serires<250000]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     242
# ...

# %%
df.index = df["account"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'account'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-547f88464418> in <module>
# ...

# %%
df.head()
# Out:
#          account                         name  \
# account
# 211829    211829   Kerluke, Koepp and Hilpert
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city          state  \
# account
# 211829                     34456 Sean Highway       New Jaycob          Texas
# 320563                      1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 121213                    7274 Marissa Common  Shanahanchester     California
#
#          postal-code     Jan     Feb    Mar
# account
# 211829         28752   10000   62000  35000
# 320563         38365   95000   45000  35000
# 648336         76517   91000  120000  35000
# ...

# %%
del df["account"]
df.head()
# Out:
#                                 name                                street  \
# account
# 211829    Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 320563                Walter-Trantow                     1311 Alvis Tunnel
# 648336    Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 109996   D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 121213                 Bauch-Goldner                   7274 Marissa Common
#
#                     city          state  postal-code     Jan     Feb    Mar
# account
# 211829        New Jaycob          Texas        28752   10000   62000  35000
# 320563     Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 648336    New Lilianland           Iowa        76517   91000  120000  35000
# 109996        Hyattburgh          Maine        46021   45000  120000  10000
# 121213   Shanahanchester     California        49681  162000  120000  35000

# %%
df[["name","street"]][:2]
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df.loc[[211829,320563],["name","street"]]
# Out:
#                                name              street
# account
# 211829   Kerluke, Koepp and Hilpert  34456 Sean Highway
# 320563               Walter-Trantow   1311 Alvis Tunnel

# %%
df[["name", "street"]].iloc[:10]
# Out:
#                                      name  \
# account
# 211829         Kerluke, Koepp and Hilpert
# 320563                     Walter-Trantow
# 648336         Bashirian, Kunde and Price
# 109996        D'Amore, Gleichner and Bode
# 121213                      Bauch-Goldner
# 132971   Williamson, Schumm and Hettinger
# 145068                         Casper LLC
# 205217                   Kovacek-Johnston
# 209744                     Champlin-Morar
# 212303                     Gerhold-Maggio
#
#                                        street
# account
# 211829                     34456 Sean Highway
# 320563                      1311 Alvis Tunnel
# 648336   62184 Schamberger Underpass Apt. 231
# 109996            155 Fadel Crescent Apt. 144
# 121213                    7274 Marissa Common
# 132971                   89403 Casimer Spring
# 145068           340 Consuela Bridge Apt. 400
# 205217           91971 Cronin Vista Suite 601
# 209744                       26739 Grant Lock
# ...

# %% [markdown]
# ### reindex

# %%
df.index = list(range(0,15))
df.head()
# Out:
#                           name                                street  \
# 0   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1               Walter-Trantow                     1311 Alvis Tunnel
# 2   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %% [markdown]
# ### data drop

# %%
df
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#       우편번호                     주소        사무실전화번호
# 0     4562    서울특별시 중구 을지로 39길 29   02-2260-7114
# ...

# %%
df.drop(1)
# Out:
#       연번   센터유형                        센터명      운영기관               시설명   우편번호  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터   국립중앙의료원        국립중앙의료원 D동   4562
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터     조선대병원    조선대학교병원 의성관 5층  61452
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터  양산 부산대병원  양산 부산대병원 기숙사동 1층  50612
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터       NaN   계명대학교 대구동산병원 별관  41931
# 5      6     지역     코로나19 서울특별시 성동구 예방접종센터       NaN      성동구청 대강당(3층)   4750
# ..   ...    ...                        ...       ...               ...    ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터       NaN           (舊)흥덕구청  28426
# 280  281     지역       코로나19 경기도 파주시 예방접종센터       NaN            운정행복센터  10894
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터       NaN          화도체육문화센터  12178
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터       NaN          시흥국민체육센터  14976
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터       NaN            국민체육센터  31772
#
# ...

# %%
df
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#       우편번호                     주소        사무실전화번호
# 0     4562    서울특별시 중구 을지로 39길 29   02-2260-7114
# ...

# %%
df.drop([0,1,2,3])
# Out:
#       연번 센터유형                        센터명 운영기관              시설명   우편번호  \
# 4      5   지역      코로나19 대구광역시 중구 예방접종센터  NaN  계명대학교 대구동산병원 별관  41931
# 5      6   지역     코로나19 서울특별시 성동구 예방접종센터  NaN     성동구청 대강당(3층)   4750
# 6      7   지역    코로나19 부산광역시 부산진구 예방접종센터  NaN     부산시민공원 시민사랑채  47197
# 7      8   지역     코로나19 인천광역시 연수구 예방접종센터  NaN      선학경기장 선학체육관  21908
# 8      9   지역      코로나19 광주광역시 서구 예방접종센터  NaN           빛고을체육관  62048
# ..   ...  ...                        ...  ...              ...    ...
# 279  280   지역  코로나19 충청북도 청주시 흥덕구 예방접종센터  NaN          (舊)흥덕구청  28426
# 280  281   지역       코로나19 경기도 파주시 예방접종센터  NaN           운정행복센터  10894
# 281  282   지역      코로나19 경기도 남양주시 예방접종센터  NaN         화도체육문화센터  12178
# 282  283   지역       코로나19 경기도 시흥시 예방접종센터  NaN         시흥국민체육센터  14976
# 283  284   지역      코로나19 충청남도 당진시 예방접종센터  NaN           국민체육센터  31772
#
#                         주소        사무실전화번호
# 4            대구시 중구 달성로 56   053-661-3955
# ...

# %%
matrix = df.as_matrix()
matrix[:3]
# Out:
# array([['Kerluke, Koepp and Hilpert', '34456 Sean Highway', 'New Jaycob',
#         'Texas', 28752, 10000, 62000, 35000],
#        ['Walter-Trantow', '1311 Alvis Tunnel', 'Port Khadijah',
#         'NorthCarolina', 38365, 95000, 45000, 35000],
#        ['Bashirian, Kunde and Price',
#         '62184 Schamberger Underpass Apt. 231', 'New Lilianland', 'Iowa',
#         76517, 91000, 120000, 35000]], dtype=object)

# %%
matrix[:,-3:]

# %%
matrix[:,-3:].sum(axis=1)

# %%
df.drop("city",axis=1).head()
# Out:
#                           name                                street  \
# 0   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1               Walter-Trantow                     1311 Alvis Tunnel
# 2   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4                Bauch-Goldner                   7274 Marissa Common
#
#            state  postal-code     Jan     Feb    Mar
# 0          Texas        28752   10000   62000  35000
# 1  NorthCarolina        38365   95000   45000  35000
# 2           Iowa        76517   91000  120000  35000
# 3          Maine        46021   45000  120000  10000
# 4     California        49681  162000  120000  35000

# %%
df
# Out:
#       연번   센터유형                        센터명       운영기관               시설명  \
# 0      1  중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1      2  중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2      3  중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3      4  중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4      5     지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..   ...    ...                        ...        ...               ...
# 279  280     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280  281     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281  282     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282  283     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283  284     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#       우편번호                     주소        사무실전화번호
# 0     4562    서울특별시 중구 을지로 39길 29   02-2260-7114
# ...

# %%
df.drop(["연번", "우편번호"],axis=1)
# Out:
#       센터유형                        센터명       운영기관               시설명  \
# 0    중앙/권역            코로나19 중앙 예방접종센터    국립중앙의료원        국립중앙의료원 D동
# 1    중앙/권역          코로나19 중부권역 예방접종센터  순천향대 천안병원    천안시 실내배드민턴장 1층
# 2    중앙/권역          코로나19 호남권역 예방접종센터      조선대병원    조선대학교병원 의성관 5층
# 3    중앙/권역          코로나19 영남권역 예방접종센터   양산 부산대병원  양산 부산대병원 기숙사동 1층
# 4       지역      코로나19 대구광역시 중구 예방접종센터        NaN   계명대학교 대구동산병원 별관
# ..     ...                        ...        ...               ...
# 279     지역  코로나19 충청북도 청주시 흥덕구 예방접종센터        NaN           (舊)흥덕구청
# 280     지역       코로나19 경기도 파주시 예방접종센터        NaN            운정행복센터
# 281     지역      코로나19 경기도 남양주시 예방접종센터        NaN          화도체육문화센터
# 282     지역       코로나19 경기도 시흥시 예방접종센터        NaN          시흥국민체육센터
# 283     지역      코로나19 충청남도 당진시 예방접종센터        NaN            국민체육센터
#
#                         주소        사무실전화번호
# 0      서울특별시 중구 을지로 39길 29   02-2260-7114
# 1    충청남도 천안시 동남구 천안대로 357            NaN
# ...

# %%
matrix = df.as_matrix()
matrix
